# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder,MinMaxScaler
from sklearn import linear_model
from sklearn.model_selection import cross_val_score, StratifiedKFold,KFold

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
#DATA PATH
DATA_PATH = './data/'

# %%
imputed_df = pd.read_csv(DATA_PATH + 'imputed_df.csv',index_col=False)

# %%
imputed_df.columns
# Out:
# Index(['Popularity', 'Artist_followers', 'Track_number', 'Tracks_in_album',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        ...
#        'viral rap', 'vlaamse kinderliedje', 'vocal harmony group', 'volkspop',
#        'world chill', 'zimdancehall', 'zouk riddim', 'year', 'month', 'day'],
#       dtype='object', length=1229)

# %%
imputed_df.columns
# Out:
# Index(['Popularity', 'Artist_followers', 'Track_number', 'Tracks_in_album',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        ...
#        'viral rap', 'vlaamse kinderliedje', 'vocal harmony group', 'volkspop',
#        'world chill', 'zimdancehall', 'zouk riddim', 'year', 'month', 'day'],
#       dtype='object', length=1229)

# %%
list(imputed_df.columns)
# Out:
# ['Popularity',
#  'Artist_followers',
#  'Track_number',
#  'Tracks_in_album',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acoustics',
#  'instrumentalness',
#  'liveliness',
#  'valence',
#  'tempo',
#  'duration_ms',
#  'time_signature',
#  'Days_since_release',
#  'Explicit_false',
#  'Explicit_true',
#  'album',
#  'compilation',
#  'single',
#  'syuzhet_norm',
#  'bing_norm',
#  'afinn_norm',
#  'nrc_norm',
#  'syuzhet',
#  'bing',
#  'afinn',
#  'nrc',
#  'anger',
#  'anticipation',
#  'disgust',
#  'fear',
#  'joy',
#  'sadness',
#  'surprise',
#  'trust',
#  'negative',
#  'positive',
#  'n_words',
#  'anger_norm',
#  'anticipation_norm',
#  'disgust_norm',
#  'fear_norm',
#  'joy_norm',
#  'sadness_norm',
#  'surprise_norm',
#  'trust_norm',
#  'negative_norm',
#  'positive_norm',
#  'negative_bog_jr',
#  'positive_bog_jr',
#  'Bayes',
#  'Negative_Bayes',
#  'Neutral_Bayes',
#  'Positive_Bayes',
#  'Celebrate',
#  'Desire',
#  'Explore',
#  'Fun',
#  'Hope',
#  'Love',
#  'Nostalgia',
#  'Thug',
#  'bing_norm_negative',
#  'bing_norm_neutral',
#  'bing_norm_positive',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Denmark',
#  'Ecuador',
#  'Finland',
#  'France',
#  'Germany',
#  'Global',
#  'Indonesia',
#  'Ireland',
#  'Italy',
#  'Malaysia',
#  'Mexico',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Singapore',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Turkey',
#  'UK',
#  'USA',
#  'Popu_max',
#  'Top10_dummy',
#  'Top50_dummy',
#  'a cappella',
#  'acid house',
#  'acoustic chill',
#  'acoustic opm',
#  'acoustic pop',
#  'adoracao',
#  'adult standards',
#  'afghan pop',
#  'african gospel',
#  'afro dancehall',
#  'afro house',
#  'afrobeat',
#  'afrobeat brasileiro',
#  'afrofuturism',
#  'afrofuturismo brasileiro',
#  'afropop',
#  'afroswing',
#  'ai',
#  'alabama indie',
#  'alabama rap',
#  'albanian hip hop',
#  'albanian pop',
#  'album rock',
#  'alternative country',
#  'alternative dance',
#  'alternative emo',
#  'alternative hip hop',
#  'alternative metal',
#  'alternative pop',
#  'alternative pop rock',
#  'alternative r&b',
#  'alternative rock',
#  'ambient folk',
#  'ambient house',
#  'ambient pop',
#  'anadolu rock',
#  'anime',
#  'anime rock',
#  'anthem',
#  'anthem worship',
#  'anti-folk',
#  'antideutsche',
#  'antilliaanse rap',
#  'antiviral pop',
#  'arab trap',
#  'arabesk',
#  'arabic hip hop',
#  'argentine alternative rock',
#  'argentine heavy metal',
#  'argentine hip hop',
#  'argentine indie',
#  'argentine punk',
#  'argentine reggae',
#  'argentine rock',
#  'argentine telepop',
#  'arkansas country',
#  'arkansas hip hop',
#  'armenian pop',
#  'art pop',
#  'art punk',
#  'art rock',
#  'asian american hip hop',
#  'atl hip hop',
#  'atl trap',
#  'aussie drill',
#  'aussietronica',
#  'australian alternative pop',
#  'australian alternative rock',
#  'australian country',
#  'australian dance',
#  'australian electropop',
#  'australian garage punk',
#  'australian hip hop',
#  'australian house',
#  'australian indie',
#  'australian indie folk',
#  'australian indigenous',
#  'australian metalcore',
#  'australian pop',
#  'australian psych',
#  'australian r&b',
#  'australian reggae fusion',
#  'australian rock',
#  'australian talent show',
#  'australian underground hip hop',
#  'austrian hip hop',
#  'austrian indie',
#  'austrian pop',
#  'austropop',
#  'avant-garde jazz',
#  'axe',
#  'azeri pop',
#  'azeri rap',
#  'azeri traditional',
#  'azonto',
#  'azontobeats',
#  'bachata',
#  'baglama',
#  'bagpipe marching band',
#  'baithak gana',
#  'balearic',
#  'balkan hip hop',
#  'balkan trap',
#  'ballroom',
#  'baltimore hip hop',
#  'banda',
#  'banjo',
#  'barbadian pop',
#  'barnemusikk',
#  'barnmusik',
#  'baroque',
#  'baroque pop',
#  'bass house',
#  'bass music',
#  'bass trap',
#  'basshall',
#  'bassline',
#  'batak',
#  'batida',
#  'batidao romantico',
#  'baton rouge rap',
#  'battle rap',
#  'bayerischer rap',
#  'bc underground hip hop',
#  'beach house',
#  'beat italiano',
#  'beatlesque',
#  'bebop',
#  'bedroom pop',
#  'bedroom soul',
#  'belarusian indie',
#  'belgian dance',
#  'belgian edm',
#  'belgian hip hop',
#  'belgian indie',
#  'belgian pop',
#  'belgian rock',
#  'belgian singer-songwriter',
#  'belo horizonte indie',
#  'bergamo indie',
#  'bergen indie',
#  'berlin minimal techno',
#  'bhangra',
#  'big band',
#  'big beat',
#  'big room',
#  'birmingham grime',
#  'birmingham hip hop',
#  'bisaya rap',
#  "black 'n' roll",
#  'blues',
#  'blues rock',
#  'bmore',
#  'bolero',
#  'boogaloo',
#  'bossa nova',
#  'boston hip hop',
#  'boston punk',
#  'bouncy house',
#  'bow pop',
#  'boy band',
#  'brazilian bass',
#  'brazilian edm',
#  'brazilian gospel',
#  'brazilian hip hop',
#  'brazilian indie',
#  'brazilian reggae',
#  'brazilian rock',
#  'brega funk',
#  'brega romantico',
#  'brighton indie',
#  'brill building pop',
#  'bristol indie',
#  'brit funk',
#  'british alternative rock',
#  'british blues',
#  'british choir',
#  'british comedy',
#  'british country',
#  'british dance band',
#  'british folk',
#  'british indie rock',
#  'british singer-songwriter',
#  'british soul',
#  'british soundtrack',
#  'britpop',
#  'broadway',
#  'bronx hip hop',
#  'brooklyn drill',
#  'brooklyn indie',
#  'brostep',
#  'bubble trance',
#  'bubblegum dance',
#  'bubblegum pop',
#  'bulgarian pop',
#  'c-pop',
#  'c86',
#  'cali rap',
#  'calming instrumental',
#  'canadian celtic',
#  'canadian contemporary country',
#  'canadian contemporary r&b',
#  'canadian country',
#  'canadian electronic',
#  'canadian electropop',
#  'canadian folk',
#  'canadian hip hop',
#  'canadian indie',
#  'canadian indie folk',
#  'canadian latin',
#  'canadian pop',
#  'canadian post-hardcore',
#  'canadian rock',
#  'canadian singer-songwriter',
#  'cancion infantil mexicana',
#  'cancion melodica',
#  'candy pop',
#  'cantautor',
#  'canti alpini',
#  'cantopop',
#  "canzone d'autore",
#  'canzone napoletana',
#  'cape town indie',
#  'carnaval',
#  'carnaval cadiz',
#  'cartoon',
#  'ccm',
#  'celtic',
#  'celtic rock',
#  'cha-cha-cha',
#  'chamame',
#  'chamber pop',
#  'chamber psych',
#  'champeta',
#  'channel islands indie',
#  'channel pop',
#  'chanson',
#  'charanga',
#  'chicago drill',
#  'chicago hardcore',
#  'chicago house',
#  'chicago rap',
#  'chicago soul',
#  'chicano rap',
#  'chicha',
#  'chihuahua indie',
#  "children's choir",
#  'chilean hardcore',
#  'chilean indie',
#  'chilean rock',
#  'chilena',
#  'chill beats',
#  'chill pop',
#  'chill r&b',
#  'chillstep',
#  'chillwave',
#  'chinderlieder',
#  'chinese audiophile',
#  'chinese drama ost',
#  'chinese electropop',
#  'chinese hip hop',
#  'chinese idol pop',
#  'chinese indie',
#  'chinese jazz',
#  'chinese manyao',
#  'chinese minyao',
#  'chinese new year',
#  'chinese r&b',
#  'chinese soundtrack',
#  'chinese viral pop',
#  'christelijk',
#  'christlicher rap',
#  'christmas instrumental',
#  'christmas product',
#  'chunchaca',
#  'circuit',
#  'classic belgian pop',
#  'classic colombian pop',
#  'classic country pop',
#  'classic danish pop',
#  'classic dutch pop',
#  'classic finnish pop',
#  'classic finnish rock',
#  'classic french pop',
#  'classic hardstyle',
#  'classic icelandic pop',
#  'classic indo pop',
#  'classic iskelma',
#  'classic italian pop',
#  'classic malaysian pop',
#  'classic mandopop',
#  'classic norwegian pop',
#  'classic nz pop',
#  'classic opm',
#  'classic peruvian pop',
#  'classic polish pop',
#  'classic portuguese pop',
#  'classic rock',
#  'classic schlager',
#  'classic soul',
#  'classic soundtrack',
#  'classic swedish pop',
#  'classic turkish pop',
#  'classic uk pop',
#  'classic venezuelan pop',
#  'classical',
#  'classical era',
#  'classical piano',
#  'classical tenor',
#  'cologne hip hop',
#  'cologne indie',
#  'colombian hip hop',
#  'colombian indie',
#  'colombian pop',
#  'colombian rock',
#  'comedy rap',
#  'comic',
#  'comic metal',
#  'complextro',
#  'compositional ambient',
#  'conscious hip hop',
#  'contemporary country',
#  'contemporary vocal jazz',
#  'copla',
#  'corrido',
#  'country',
#  'country dawn',
#  'country rap',
#  'country rock',
#  'croatian pop',
#  'crossover thrash',
#  'crunk',
#  'cuarteto',
#  'cuatro venezolano',
#  'cubaton',
#  'cueca chilena',
#  'cumbia',
#  'cumbia chilena',
#  'cumbia ecuatoriana',
#  'cumbia paraguaya',
#  'cumbia peruana',
#  'cumbia pop',
#  'cumbia ranchera',
#  'cumbia sonidera',
#  'cumbia villera',
#  'cyber metal',
#  'cypriot pop',
#  'czech pop',
#  'dakke dak',
#  'dalarna indie',
#  'dance pop',
#  'dance rock',
#  'dancehall',
#  'dangdut',
#  'dangdut koplo',
#  'dangdut remix',
#  'danish alternative rock',
#  'danish electronic',
#  'danish electropop',
#  'danish hip hop',
#  'danish pop',
#  'danish pop rock',
#  'danish singer-songwriter',
#  'dansband',
#  'danseband',
#  'dansktop',
#  'danspunk',
#  'dark disco',
#  'dark trap',
#  'deconstructed club',
#  'deep big room',
#  'deep disco house',
#  'deep euro house',
#  'deep german hip hop',
#  'deep groove house',
#  'deep house',
#  'deep indian pop',
#  'deep italo disco',
#  'deep neofolk',
#  'deep pop edm',
#  'deep rai',
#  'deep soft rock',
#  'deep talent show',
#  'deep tech house',
#  'deep tropical house',
#  'deep turkish pop',
#  'deep underground hip hop',
#  'deep uplifting trance',
#  'dembow',
#  'desi hip hop',
#  'desi pop',
#  'destroy techno',
#  'detroit hip hop',
#  'detroit trap',
#  'detske pisnicky',
#  'devon indie',
#  'dfw rap',
#  'dirty south rap',
#  'disco',
#  'disco house',
#  'disco polo',
#  'discofox',
#  'disney',
#  'disney espanol',
#  'diva house',
#  'dmv rap',
#  'dominican indie',
#  'dominican pop',
#  'double drumming',
#  'downtempo',
#  'dream trance',
#  'drill espanol',
#  'drill francais',
#  'drill tuga',
#  'drum and bass',
#  'dubstep',
#  'dubsteppe',
#  'dutch americana',
#  'dutch cabaret',
#  'dutch drill',
#  'dutch edm',
#  'dutch hip hop',
#  'dutch house',
#  'dutch idol pop',
#  'dutch indie',
#  'dutch metal',
#  'dutch moombahton',
#  'dutch pop',
#  'dutch r&b',
#  'dutch rap pop',
#  'dutch singer-songwriter',
#  'dutch trance',
#  'dutch trap',
#  'early modern classical',
#  'early romantic era',
#  'east coast hip hop',
#  'easy listening',
#  'eau claire indie',
#  'ecuadorian alternative rock',
#  'ecuadorian pop',
#  'edm',
#  'edmonton indie',
#  'electra',
#  'electro',
#  'electro bailando',
#  'electro dub',
#  'electro house',
#  'electro latino',
#  'electro swing',
#  'electrofox',
#  'electronic trap',
#  'electronica',
#  'electronica argentina',
#  'electropop',
#  'electropowerpop',
#  'emo',
#  'emo mexicano',
#  'emo rap',
#  'emo rap italiano',
#  'english indie rock',
#  'epicore',
#  'escape room',
#  'estonian electronic',
#  'estonian hip hop',
#  'etherpop',
#  'eurodance',
#  'europop',
#  'eurovision',
#  'exotica',
#  'fado',
#  'filmi',
#  'filter house',
#  'finlandssvenska musik',
#  'finnish alternative rock',
#  'finnish blues',
#  'finnish choir',
#  'finnish dance pop',
#  'finnish death metal',
#  'finnish edm',
#  'finnish electro',
#  'finnish hard rock',
#  'finnish heavy metal',
#  'finnish hip hop',
#  'finnish idol pop',
#  'finnish indie',
#  'finnish jazz',
#  'finnish metal',
#  'finnish new wave',
#  'finnish pop',
#  'finnish punk',
#  'finnish reggae',
#  'finnish trap',
#  'firenze indie',
#  'flamenco',
#  'flamenco urbano',
#  'florida rap',
#  'folclore salteno',
#  'folk',
#  'folk black metal',
#  'folk brasileiro',
#  'folk rock',
#  'folk rock italiano',
#  'folk-pop',
#  'folklore chileno',
#  'folklore peruano',
#  'folklore veracruzano',
#  'football',
#  'forro',
#  'forro de favela',
#  'francoton',
#  'frauenrap',
#  'freak folk',
#  'french hip hop',
#  'french indie folk',
#  'french indie pop',
#  'french pop',
#  'french reggae',
#  'french shoegaze',
#  'french synthpop',
#  'funk',
#  'funk 150 bpm',
#  'funk bh',
#  'funk carioca',
#  'funk consciente',
#  'funk das antigas',
#  'funk metal',
#  'funk ostentacao',
#  'funk paulista',
#  'funk pop',
#  'future bass',
#  'futurepop',
#  'g funk',
#  'gabba',
#  'gaming dubstep',
#  'gaming edm',
#  'gangster rap',
#  'garage rock',
#  'gauze pop',
#  'german alternative rap',
#  'german alternative rock',
#  'german cloud rap',
#  'german dance',
#  'german drill',
#  'german hard rock',
#  'german hip hop',
#  'german house',
#  'german indie',
#  'german pop',
#  'german pop rock',
#  'german r&b',
#  'german rock',
#  'german show tunes',
#  'german soundtrack',
#  'german trap',
#  'german underground rap',
#  'girl group',
#  'glam metal',
#  'glam rock',
#  'glasgow indie',
#  'glee club',
#  'glitchcore',
#  'goralski',
#  'gospel',
#  'gospel italiano',
#  'gothenburg hip hop',
#  'gothenburg indie',
#  'gothic symphonic metal',
#  'gotlandsk musik',
#  'gqom',
#  'granada indie',
#  'graz indie',
#  'greek hip hop',
#  'greek house',
#  'greek indie',
#  'greenlandic pop',
#  'grime',
#  'groove room',
#  'grupera',
#  'gruperas inmortales',
#  'guadalajara indie',
#  'guaracha',
#  'guatemalan pop',
#  'hakkapop',
#  'halifax indie',
#  'halloween',
#  'hamburg electronic',
#  'hands up',
#  'hard bass',
#  'hard rock',
#  'hawaiian hip hop',
#  'heartland rock',
#  'hi-nrg',
#  'hip hop',
#  'hip hop quebecois',
#  'hip hop tuga',
#  'hip house',
#  'hip pop',
#  'hoerspiel',
#  'hokkien pop',
#  'hollywood',
#  'hong kong hip hop',
#  'hong kong indie',
#  'hopebeat',
#  'horror synth',
#  'house',
#  'houston rap',
#  'hungarian metal',
#  'hungarian pop',
#  'icelandic electronic',
#  'icelandic folk',
#  'icelandic indie',
#  'icelandic pop',
#  'idol',
#  'indie anthem-folk',
#  'indie cafe pop',
#  'indie deutschrap',
#  'indie electropop',
#  'indie extremena',
#  'indie folk',
#  'indie folk italiano',
#  'indie liguria',
#  'indie pop',
#  'indie pop rap',
#  'indie poptimism',
#  'indie rock',
#  'indie rock italiano',
#  'indie rock mexicano',
#  'indie rock peruano',
#  'indie rockism',
#  'indie singer-songwriter',
#  'indie soul',
#  'indie tico',
#  'indie triste',
#  'indiecoustica',
#  'indietronica',
#  'indonesian alternative rock',
#  'indonesian city pop',
#  'indonesian edm',
#  'indonesian emo',
#  'indonesian folk',
#  'indonesian hip hop',
#  'indonesian idol pop',
#  'indonesian indie',
#  'indonesian jazz',
#  'indonesian pop',
#  'indonesian pop punk',
#  'indonesian r&b',
#  'indonesian rock',
#  'indy indie',
#  'instrumental math rock',
#  'irish ballad',
#  'irish country',
#  'irish hip hop',
#  'irish indie',
#  'irish pop',
#  'irish rock',
#  'irish singer-songwriter',
#  'iskelma',
#  'isle of wight indie',
#  'israeli indie',
#  'israeli pop',
#  'italian adult pop',
#  'italian alternative',
#  'italian hip hop',
#  'italian indie pop',
#  'italian new wave',
#  'italian pop',
#  'italian progressive rock',
#  'italo dance',
#  'j-dance',
#  'j-division',
#  'j-idol',
#  'j-pop',
#  'j-rock',
#  'jam band',
#  'japanese alternative rock',
#  'japanese r&b',
#  'javanese dangdut',
#  'jawaiian',
#  'jazz blues',
#  'jazz funk',
#  'jazz pop',
#  'jersey club',
#  'jewish pop',
#  'jovem guarda',
#  'jump up',
#  'k-indie',
#  'k-pop',
#  'k-pop boy group',
#  'k-pop girl group',
#  'k-rap',
#  'kabyle',
#  'karadeniz halk muzigi',
#  'karneval',
#  'kawaii future bass',
#  'kazakh pop',
#  'kentucky hip hop',
#  'kentucky indie',
#  'kenyan pop',
#  'kindermusik',
#  'kiwi rock',
#  'kizomba',
#  'kleinkunst',
#  'kolsche karneval',
#  'korean ost',
#  'korean pop',
#  'korean r&b',
#  'kurdish pop',
#  'la indie',
#  'la pop',
#  'latin',
#  'latin alternative',
#  'latin arena pop',
#  'latin christian',
#  'latin hip hop',
#  'latin jazz',
#  'latin pop',
#  'latin rock',
#  'latin talent show',
#  'latin viral pop',
#  'latin worship',
#  'latintronica',
#  'lds youth',
#  'leeds indie',
#  'lilith',
#  'lithuanian electronic',
#  'lithuanian pop',
#  'lo-fi beats',
#  'lo-fi cover',
#  'london indie',
#  'london rap',
#  'lustrum',
#  'luxembourgian hip hop',
#  'macedonian pop',
#  'madchester',
#  'mainland chinese pop',
#  'malay rap',
#  'malaysian hip hop',
#  'malaysian indie',
#  'malaysian mandopop',
#  'malaysian pop',
#  'malaysian tamil pop',
#  'maltese pop',
#  'mambo chileno',
#  'manchester hip hop',
#  'mandopop',
#  'marching band',
#  'mariachi',
#  'melancholia',
#  'melbourne bounce',
#  'melbourne bounce international',
#  'mellow gold',
#  'melodic metalcore',
#  'melodic rap',
#  'melodipop',
#  'meme rap',
#  'memphis hip hop',
#  'merengue',
#  'metal',
#  'metropopolis',
#  'mexican edm',
#  'mexican hip hop',
#  'mexican indie',
#  'mexican pop',
#  'miami hip hop',
#  'midwest americana',
#  'military band',
#  'milwaukee indie',
#  'modern alternative pop',
#  'modern alternative rock',
#  'modern blues',
#  'modern blues rock',
#  'modern folk rock',
#  'modern indie pop',
#  'modern reggae',
#  'modern rock',
#  'modern salsa',
#  'moombahton',
#  'moroccan pop',
#  'motown',
#  'movie tunes',
#  'mpb',
#  'mundart',
#  'music hall',
#  'musica andina',
#  'musica andorra',
#  'musica catalana',
#  'musica costarricense',
#  'musica de intervencao',
#  'musica etnica',
#  'musica gaucha',
#  'musica para ninos',
#  'musica popular colombiana',
#  'musica portuguesa contemporanea',
#  'musical advocacy',
#  'musiikkia lapsille',
#  'musik anak-anak',
#  'musique guadeloupe',
#  'muziek voor kinderen',
#  'nasheed',
#  'nashville singer-songwriter',
#  'nashville sound',
#  'native american',
#  'nederlandse hardstyle',
#  'neo mellow',
#  'neo r&b',
#  'neo soul',
#  'neo-psychedelic',
#  'neo-singer-songwriter',
#  'neomelodici',
#  'neon pop punk',
#  'nerdcore brasileiro',
#  'new french touch',
#  'new jersey rap',
#  'new wave pop',
#  'new weird finland',
#  'nordic house',
#  'norges stemme',
#  'norteno',
#  'north carolina hip hop',
#  'norwegian choir',
#  'norwegian classical',
#  'norwegian contemporary jazz',
#  'norwegian country',
#  'norwegian hip hop',
#  'norwegian indie',
#  'norwegian pop',
#  'norwegian pop rap',
#  'nova mpb',
#  'novelty',
#  'nu-cumbia',
#  'nueva cancion',
#  'nuevo flamenco',
#  'nuevo regional mexicano',
#  'nyc pop',
#  'nyc rap',
#  'nz electronic',
#  'nz hip hop',
#  'nz pop',
#  'nz reggae',
#  'ohio hip hop',
#  'oktoberfest',
#  'operatic pop',
#  'operetta',
#  'opm',
#  'orebro indie',
#  'oriental metal',
#  'oslo indie',
#  'ottawa rap',
#  'oulu indie',
#  'oyun havasi',
#  'pagode',
#  'palm desert scene',
#  'panamanian pop',
#  'partyschlager',
#  'permanent wave',
#  'perreo',
#  'persian pop',
#  'peruvian rock',
#  'piano rock',
#  'pinoy alternative rap',
#  'pinoy hip hop',
#  'pinoy indie',
#  'pinoy r&b',
#  'pinoy singer-songwriter',
#  'pittsburgh indie',
#  'poezja spiewana',
#  'polish alternative',
#  'polish alternative rap',
#  'polish alternative rock',
#  'polish blues',
#  'polish electronica',
#  'polish hip hop',
#  'polish indie',
#  'polish metal',
#  'polish pop',
#  'polish punk',
#  'polish rock',
#  'polish trap',
#  'polynesian pop',
#  'pop',
#  'pop argentino',
#  'pop chileno',
#  'pop costarricense',
#  'pop dance',
#  'pop edm',
#  'pop flamenco',
#  'pop folk',
#  'pop house',
#  'pop nacional',
#  'pop peruano',
#  'pop punk',
#  'pop quebecois',
#  ...]

# %%
countries = list(imputed_df.columns)[69:104]

# %% [markdown]
# # Modeling

# %% [markdown]
# ## 1. Linear Regression

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True,random_state=42)

# %%
def print_scores(data,label,data_type,model,features,country):
    pipe_cls = None
    data = data[data[country]==1]
    if(model == 'linear regression'):
        pipe_cls = Pipeline([('preprocess',StandardScaler()),
                            ('clf', linear_model.LinearRegression())])
    elif(model == 'Decision tree regression'):
        pipe_cls = Pipeline([('preprocess',StandardScaler()),
                            ('clf', DecisionTreeRegressor())])
        
    kf = KFold(n_splits=5,random_state=42,shuffle=True)
    
    r2 = cross_val_score(pipe_cls, data[features], data[label],cv=kf,scoring='r2')
    
    print("data type: {}\nlabel: {}\nmodel : {}\n country: {}".format(data_type,label,model,country))
    print("r2 score: {}".format(np.mean(r2)))
    print()
    
    variance = cross_val_score(pipe_cls, data[features], data[label],cv=kf,scoring='explained_variance')
    
    print("data type: {}\nlabel: {}\nmodel : {}\n country: {}".format(data_type,label,model,country))
    print("variance score: {}".format(np.mean(variance)))
    print()
    
    rmse = cross_val_score(pipe_cls, data[features], data[label],cv=kf,scoring='neg_root_mean_squared_error')
    
    print("data type: {}\nlabel: {}\nmodel : {}\n country: {}".format(data_type,label,model,country))
    print("rmse score: {}".format(-1*np.mean(rmse)))
    print()

# %%
features_columns = [column for column in imputed_df.columns if column!='Popularity']

# %%
len(features_columns)
# Out:
# 1228

# %%
for country in countries:
    print_scores(imputed_df,'Popularity','imputed_df','linear regression',features_columns,country)
# Out:
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Argentina
# r2 score: -4.808593981663946e+22
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Argentina
# variance score: -4.79689031050006e+22
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Argentina
# rmse score: 2755125881638297.5
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Australia
# r2 score: -5.532453262881367e+22
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Australia
# variance score: -5.528982944378582e+22
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Australia
# rmse score: 2597360676050038.5
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Austria
# r2 score: -1.8096857239324643e+23
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Austria
# variance score: -1.8093210735566873e+23
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Austria
# rmse score: 3726128050956493.0
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Belgium
# r2 score: -7.375169077219539e+22
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Belgium
# variance score: -7.357814883921465e+22
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Belgium
# rmse score: 2879546404590726.5
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Brazil
# r2 score: -2.602019883710761e+22
#
# data type: imputed_df
# label: Popularity
# model : linear regression
#  country: Brazil
# variance score: -2.593389329808445e+22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [33], line 2
#       1 for country in countries:
# ----> 2     print_scores(imputed_df,'Popularity','imputed_df','linear regression',features_columns,country)
#
# Cell In [30], line 25, in print_scores(data, label, data_type, model, features, country)
#      22 print("variance score: {}".format(np.mean(variance)))
#      23 print()
# ---> 25 rmse = cross_val_score(pipe_cls, data[features], data[label],cv=kf,scoring='neg_root_mean_squared_error')
#      27 print("data type: {}\nlabel: {}\nmodel : {}\n country: {}".format(data_type,label,model,country))
#      28 print("rmse score: {}".format(-1*np.mean(rmse)))
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/parallel.py:1048, in Parallel.__call__(self, iterable)
#    1039 try:
#    1040     # Only set self._iterating to True if at least a batch
#    1041     # was dispatched. In particular this covers the edge
#    (...)
#    1045     # was very quick and its callback already dispatched all the
#    1046     # remaining jobs.
#    1047     self._iterating = False
# -> 1048     if self.dispatch_one_batch(iterator):
#    1049         self._iterating = self._original_iterator is not None
#    1051     while self.dispatch_one_batch(iterator):
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/pipeline.py:382, in Pipeline.fit(self, X, y, **fit_params)
#     380     if self._final_estimator != "passthrough":
#     381         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 382         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     384 return self
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/linear_model/_base.py:736, in LinearRegression.fit(self, X, y, sample_weight)
#     734         self.coef_ = np.vstack([out[0] for out in outs])
#     735 else:
# --> 736     self.coef_, _, self.rank_, self.singular_ = linalg.lstsq(X, y)
#     737     self.coef_ = self.coef_.T
#     739 if y.ndim == 1:
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/scipy/linalg/_basic.py:1192, in lstsq(a, b, cond, overwrite_a, overwrite_b, check_finite, lapack_driver)
#    1190 if real_data:
#    1191     lwork, iwork = _compute_lwork(lapack_lwork, m, n, nrhs, cond)
# -> 1192     x, s, rank, info = lapack_func(a1, b1, lwork,
#    1193                                    iwork, cond, False, False)
#    1194 else:  # complex data
#    1195     lwork, rwork, iwork = _compute_lwork(lapack_lwork, m, n,
#    1196                                          nrhs, cond)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 1. Decision tree Regression

# %%
for country in countries:
    print_scores(imputed_df,'Popularity','imputed_df','Decision tree regression',features_columns,country)
# Out:
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Argentina
# r2 score: 0.37018563795930515
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Argentina
# variance score: 0.3710338079975878
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Argentina
# rmse score: 12506.157297055015
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Australia
# r2 score: -0.016197613933810074
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Australia
# variance score: 0.05589583000502683
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Australia
# rmse score: 14466.374789142885
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Austria
# r2 score: 0.14631292564943874
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Austria
# variance score: 0.13530807192909428
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Austria
# rmse score: 9176.870764512109
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Belgium
# r2 score: 0.007678256192038413
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Belgium
# variance score: 0.09253602337725682
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Belgium
# rmse score: 11189.885947239463
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Brazil
# r2 score: 0.35701664005688466
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Brazil
# variance score: 0.35234446257802937
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Brazil
# rmse score: 12627.273167424117
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Canada
# r2 score: -0.010669305479429726
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Canada
# variance score: 0.019403178437319313
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Canada
# rmse score: 11524.355110244302
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Chile
# r2 score: 0.4979696624369109
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Chile
# variance score: 0.5009097151498929
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Chile
# rmse score: 11062.319418276295
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Colombia
# r2 score: 0.402440875548434
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Colombia
# variance score: 0.37433147755529267
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Colombia
# rmse score: 13571.756108652897
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Costa Rica
# r2 score: 0.2890689078587272
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Costa Rica
# variance score: 0.3175005051923326
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Costa Rica
# rmse score: 14772.391118638217
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Denmark
# r2 score: 0.11799010844535218
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Denmark
# variance score: 0.12474183233928607
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Denmark
# rmse score: 10225.325993344895
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Ecuador
# r2 score: 0.40035597449200894
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Ecuador
# variance score: 0.4237152247108765
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Ecuador
# rmse score: 14080.488925452952
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Finland
# r2 score: 0.15844832550539692
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Finland
# variance score: 0.12876503826164387
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Finland
# rmse score: 8567.659758057665
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: France
# r2 score: 0.007697085850976948
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: France
# variance score: 0.03199520831656426
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: France
# rmse score: 9090.12922100943
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Germany
# r2 score: 0.13674728815010329
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Germany
# variance score: 0.1525062027069308
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Germany
# rmse score: 7632.161194952705
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Global
# r2 score: -0.04657889779928197
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Global
# variance score: -0.06187587470057134
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Global
# rmse score: 12417.736632463575
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Indonesia
# r2 score: 0.003965777595256426
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Indonesia
# variance score: -0.07094901115452086
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Indonesia
# rmse score: 18720.44759178076
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Ireland
# r2 score: 0.24508287260039116
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Ireland
# variance score: 0.22708748897492465
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Ireland
# rmse score: 10155.381617985844
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Italy
# r2 score: -0.0758497974454824
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Italy
# variance score: -0.03319131658895593
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Italy
# rmse score: 11462.90160274268
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Malaysia
# r2 score: -0.013075128938365288
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Malaysia
# variance score: -0.0379216836709658
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Malaysia
# rmse score: 14875.757740090117
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Mexico
# r2 score: 0.3561751504880296
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Mexico
# variance score: 0.37308471714960334
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Mexico
# rmse score: 14471.873973804633
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Netherlands
# r2 score: 0.28471101874260685
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Netherlands
# variance score: 0.28028126018522503
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Netherlands
# rmse score: 8061.777492857972
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: New Zealand
# r2 score: -0.03857705243570162
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: New Zealand
# variance score: -0.023537020706979116
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: New Zealand
# rmse score: 15124.913513086882
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Norway
# r2 score: 0.2545699627366632
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Norway
# variance score: 0.26285620960527123
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Norway
# rmse score: 9602.489391746436
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Peru
# r2 score: 0.5022673618808392
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Peru
# variance score: 0.4867362632065295
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Peru
# rmse score: 13135.280477475002
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Philippines
# r2 score: 0.3434847962383857
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Philippines
# variance score: 0.2175991035559377
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Philippines
# rmse score: 18452.133726457345
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Poland
# r2 score: -0.03668969222307854
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Poland
# variance score: -0.03707537144539119
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Poland
# rmse score: 12009.19351579653
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Portugal
# r2 score: 0.15891994173479176
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Portugal
# variance score: 0.16715092344412363
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Portugal
# rmse score: 12622.717191584528
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Singapore
# r2 score: 0.06183075832458011
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Singapore
# variance score: 0.09121045905995953
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Singapore
# rmse score: 17444.154199764867
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Spain
# r2 score: 0.475805863248147
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Spain
# variance score: 0.4842585828827672
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Spain
# rmse score: 9132.843363939186
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Sweden
# r2 score: 0.04620061679699026
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Sweden
# variance score: 0.019240378460280993
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Sweden
# rmse score: 9184.484232397188
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Switzerland
# r2 score: 0.07036451325202801
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Switzerland
# variance score: 0.05544159816748735
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Switzerland
# rmse score: 8924.167787995717
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Taiwan
# r2 score: -0.07856320084654969
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Taiwan
# variance score: -0.0026703752658655323
#
# data type: imputed_df
# label: Popularity
# model : Decision tree regression
#  country: Taiwan
# rmse score: 12221.955697034984
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [43], line 2
#       1 for country in countries:
# ----> 2     print_scores(imputed_df,'Popularity','imputed_df','Decision tree regression',features_columns,country)
#
# Cell In [42], line 13, in print_scores(data, label, data_type, model, features, country)
#       8     pipe_cls = Pipeline([('preprocess',StandardScaler()),
#       9                         ('clf', DecisionTreeRegressor())])
#      11 kf = KFold(n_splits=5,random_state=42,shuffle=True)
# ---> 13 r2 = cross_val_score(pipe_cls, data[features], data[label],cv=kf,scoring='r2')
#      15 print("data type: {}\nlabel: {}\nmodel : {}\n country: {}".format(data_type,label,model,country))
#      16 print("r2 score: {}".format(np.mean(r2)))
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/parallel.py:1051, in Parallel.__call__(self, iterable)
#    1048 if self.dispatch_one_batch(iterator):
#    1049     self._iterating = self._original_iterator is not None
# -> 1051 while self.dispatch_one_batch(iterator):
#    1052     pass
#    1054 if pre_dispatch == "all" or n_jobs == 1:
#    1055     # The iterable was consumed all at once by the above for loop.
#    1056     # No need to wait for async callbacks to trigger to
#    1057     # consumption.
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/joblib/parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/pipeline.py:382, in Pipeline.fit(self, X, y, **fit_params)
#     380     if self._final_estimator != "passthrough":
#     381         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 382         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     384 return self
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/tree/_classes.py:1342, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1313 def fit(self, X, y, sample_weight=None, check_input=True):
#    1314     """Build a decision tree regressor from the training set (X, y).
#    1315
#    1316     Parameters
#    (...)
#    1339         Fitted estimator.
#    1340     """
# -> 1342     super().fit(
#    1343         X,
#    1344         y,
#    1345         sample_weight=sample_weight,
#    1346         check_input=check_input,
#    1347     )
#    1348     return self
#
# File ~/opt/anaconda3/envs/mlbd/lib/python3.10/site-packages/sklearn/tree/_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
print(-1.9850923944007732e+20)
# Out:
# -1.9850923944007732e+20

# %%
2e2
# Out:
# 200.0

# %%
LinearRegression()
