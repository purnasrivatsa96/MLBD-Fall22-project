# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder,MinMaxScaler
from sklearn import linear_model
from sklearn.model_selection import cross_val_score, StratifiedKFold,KFold

# %%
from tqdm.notebook import tqdm

# %%
import pickle

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
#DATA PATH
DATA_PATH = './data/'

#MODELS_PATH
MODELS_PATH = './models/'

# %%
df_feature_engineered = pd.read_csv(DATA_PATH + 'df_feature_engineered.csv',index_col=False)

# %%
df_feature_engineered.columns
# Out:
# Index(['Popularity', 'Artist_followers', 'Track_number', 'Tracks_in_album',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        ...
#        'viral rap', 'vlaamse kinderliedje', 'vocal harmony group', 'volkspop',
#        'world chill', 'zimdancehall', 'zouk riddim', 'year', 'month', 'day'],
#       dtype='object', length=1229)

# %%
df_feature_engineered.columns
# Out:
# Index(['Popularity', 'Artist_followers', 'Track_number', 'Tracks_in_album',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        ...
#        'viral rap', 'vlaamse kinderliedje', 'vocal harmony group', 'volkspop',
#        'world chill', 'zimdancehall', 'zouk riddim', 'year', 'month', 'day'],
#       dtype='object', length=1229)

# %%
list(df_feature_engineered.columns)
# Out:
# ['Popularity',
#  'Artist_followers',
#  'Track_number',
#  'Tracks_in_album',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acoustics',
#  'instrumentalness',
#  'liveliness',
#  'valence',
#  'tempo',
#  'duration_ms',
#  'time_signature',
#  'Days_since_release',
#  'Explicit_false',
#  'Explicit_true',
#  'album',
#  'compilation',
#  'single',
#  'syuzhet_norm',
#  'bing_norm',
#  'afinn_norm',
#  'nrc_norm',
#  'syuzhet',
#  'bing',
#  'afinn',
#  'nrc',
#  'anger',
#  'anticipation',
#  'disgust',
#  'fear',
#  'joy',
#  'sadness',
#  'surprise',
#  'trust',
#  'negative',
#  'positive',
#  'n_words',
#  'anger_norm',
#  'anticipation_norm',
#  'disgust_norm',
#  'fear_norm',
#  'joy_norm',
#  'sadness_norm',
#  'surprise_norm',
#  'trust_norm',
#  'negative_norm',
#  'positive_norm',
#  'negative_bog_jr',
#  'positive_bog_jr',
#  'Bayes',
#  'Negative_Bayes',
#  'Neutral_Bayes',
#  'Positive_Bayes',
#  'Celebrate',
#  'Desire',
#  'Explore',
#  'Fun',
#  'Hope',
#  'Love',
#  'Nostalgia',
#  'Thug',
#  'bing_norm_negative',
#  'bing_norm_neutral',
#  'bing_norm_positive',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Denmark',
#  'Ecuador',
#  'Finland',
#  'France',
#  'Germany',
#  'Global',
#  'Indonesia',
#  'Ireland',
#  'Italy',
#  'Malaysia',
#  'Mexico',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Singapore',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Turkey',
#  'UK',
#  'USA',
#  'Popu_max',
#  'Top10_dummy',
#  'Top50_dummy',
#  'a cappella',
#  'acid house',
#  'acoustic chill',
#  'acoustic opm',
#  'acoustic pop',
#  'adoracao',
#  'adult standards',
#  'afghan pop',
#  'african gospel',
#  'afro dancehall',
#  'afro house',
#  'afrobeat',
#  'afrobeat brasileiro',
#  'afrofuturism',
#  'afrofuturismo brasileiro',
#  'afropop',
#  'afroswing',
#  'ai',
#  'alabama indie',
#  'alabama rap',
#  'albanian hip hop',
#  'albanian pop',
#  'album rock',
#  'alternative country',
#  'alternative dance',
#  'alternative emo',
#  'alternative hip hop',
#  'alternative metal',
#  'alternative pop',
#  'alternative pop rock',
#  'alternative r&b',
#  'alternative rock',
#  'ambient folk',
#  'ambient house',
#  'ambient pop',
#  'anadolu rock',
#  'anime',
#  'anime rock',
#  'anthem',
#  'anthem worship',
#  'anti-folk',
#  'antideutsche',
#  'antilliaanse rap',
#  'antiviral pop',
#  'arab trap',
#  'arabesk',
#  'arabic hip hop',
#  'argentine alternative rock',
#  'argentine heavy metal',
#  'argentine hip hop',
#  'argentine indie',
#  'argentine punk',
#  'argentine reggae',
#  'argentine rock',
#  'argentine telepop',
#  'arkansas country',
#  'arkansas hip hop',
#  'armenian pop',
#  'art pop',
#  'art punk',
#  'art rock',
#  'asian american hip hop',
#  'atl hip hop',
#  'atl trap',
#  'aussie drill',
#  'aussietronica',
#  'australian alternative pop',
#  'australian alternative rock',
#  'australian country',
#  'australian dance',
#  'australian electropop',
#  'australian garage punk',
#  'australian hip hop',
#  'australian house',
#  'australian indie',
#  'australian indie folk',
#  'australian indigenous',
#  'australian metalcore',
#  'australian pop',
#  'australian psych',
#  'australian r&b',
#  'australian reggae fusion',
#  'australian rock',
#  'australian talent show',
#  'australian underground hip hop',
#  'austrian hip hop',
#  'austrian indie',
#  'austrian pop',
#  'austropop',
#  'avant-garde jazz',
#  'axe',
#  'azeri pop',
#  'azeri rap',
#  'azeri traditional',
#  'azonto',
#  'azontobeats',
#  'bachata',
#  'baglama',
#  'bagpipe marching band',
#  'baithak gana',
#  'balearic',
#  'balkan hip hop',
#  'balkan trap',
#  'ballroom',
#  'baltimore hip hop',
#  'banda',
#  'banjo',
#  'barbadian pop',
#  'barnemusikk',
#  'barnmusik',
#  'baroque',
#  'baroque pop',
#  'bass house',
#  'bass music',
#  'bass trap',
#  'basshall',
#  'bassline',
#  'batak',
#  'batida',
#  'batidao romantico',
#  'baton rouge rap',
#  'battle rap',
#  'bayerischer rap',
#  'bc underground hip hop',
#  'beach house',
#  'beat italiano',
#  'beatlesque',
#  'bebop',
#  'bedroom pop',
#  'bedroom soul',
#  'belarusian indie',
#  'belgian dance',
#  'belgian edm',
#  'belgian hip hop',
#  'belgian indie',
#  'belgian pop',
#  'belgian rock',
#  'belgian singer-songwriter',
#  'belo horizonte indie',
#  'bergamo indie',
#  'bergen indie',
#  'berlin minimal techno',
#  'bhangra',
#  'big band',
#  'big beat',
#  'big room',
#  'birmingham grime',
#  'birmingham hip hop',
#  'bisaya rap',
#  "black 'n' roll",
#  'blues',
#  'blues rock',
#  'bmore',
#  'bolero',
#  'boogaloo',
#  'bossa nova',
#  'boston hip hop',
#  'boston punk',
#  'bouncy house',
#  'bow pop',
#  'boy band',
#  'brazilian bass',
#  'brazilian edm',
#  'brazilian gospel',
#  'brazilian hip hop',
#  'brazilian indie',
#  'brazilian reggae',
#  'brazilian rock',
#  'brega funk',
#  'brega romantico',
#  'brighton indie',
#  'brill building pop',
#  'bristol indie',
#  'brit funk',
#  'british alternative rock',
#  'british blues',
#  'british choir',
#  'british comedy',
#  'british country',
#  'british dance band',
#  'british folk',
#  'british indie rock',
#  'british singer-songwriter',
#  'british soul',
#  'british soundtrack',
#  'britpop',
#  'broadway',
#  'bronx hip hop',
#  'brooklyn drill',
#  'brooklyn indie',
#  'brostep',
#  'bubble trance',
#  'bubblegum dance',
#  'bubblegum pop',
#  'bulgarian pop',
#  'c-pop',
#  'c86',
#  'cali rap',
#  'calming instrumental',
#  'canadian celtic',
#  'canadian contemporary country',
#  'canadian contemporary r&b',
#  'canadian country',
#  'canadian electronic',
#  'canadian electropop',
#  'canadian folk',
#  'canadian hip hop',
#  'canadian indie',
#  'canadian indie folk',
#  'canadian latin',
#  'canadian pop',
#  'canadian post-hardcore',
#  'canadian rock',
#  'canadian singer-songwriter',
#  'cancion infantil mexicana',
#  'cancion melodica',
#  'candy pop',
#  'cantautor',
#  'canti alpini',
#  'cantopop',
#  "canzone d'autore",
#  'canzone napoletana',
#  'cape town indie',
#  'carnaval',
#  'carnaval cadiz',
#  'cartoon',
#  'ccm',
#  'celtic',
#  'celtic rock',
#  'cha-cha-cha',
#  'chamame',
#  'chamber pop',
#  'chamber psych',
#  'champeta',
#  'channel islands indie',
#  'channel pop',
#  'chanson',
#  'charanga',
#  'chicago drill',
#  'chicago hardcore',
#  'chicago house',
#  'chicago rap',
#  'chicago soul',
#  'chicano rap',
#  'chicha',
#  'chihuahua indie',
#  "children's choir",
#  'chilean hardcore',
#  'chilean indie',
#  'chilean rock',
#  'chilena',
#  'chill beats',
#  'chill pop',
#  'chill r&b',
#  'chillstep',
#  'chillwave',
#  'chinderlieder',
#  'chinese audiophile',
#  'chinese drama ost',
#  'chinese electropop',
#  'chinese hip hop',
#  'chinese idol pop',
#  'chinese indie',
#  'chinese jazz',
#  'chinese manyao',
#  'chinese minyao',
#  'chinese new year',
#  'chinese r&b',
#  'chinese soundtrack',
#  'chinese viral pop',
#  'christelijk',
#  'christlicher rap',
#  'christmas instrumental',
#  'christmas product',
#  'chunchaca',
#  'circuit',
#  'classic belgian pop',
#  'classic colombian pop',
#  'classic country pop',
#  'classic danish pop',
#  'classic dutch pop',
#  'classic finnish pop',
#  'classic finnish rock',
#  'classic french pop',
#  'classic hardstyle',
#  'classic icelandic pop',
#  'classic indo pop',
#  'classic iskelma',
#  'classic italian pop',
#  'classic malaysian pop',
#  'classic mandopop',
#  'classic norwegian pop',
#  'classic nz pop',
#  'classic opm',
#  'classic peruvian pop',
#  'classic polish pop',
#  'classic portuguese pop',
#  'classic rock',
#  'classic schlager',
#  'classic soul',
#  'classic soundtrack',
#  'classic swedish pop',
#  'classic turkish pop',
#  'classic uk pop',
#  'classic venezuelan pop',
#  'classical',
#  'classical era',
#  'classical piano',
#  'classical tenor',
#  'cologne hip hop',
#  'cologne indie',
#  'colombian hip hop',
#  'colombian indie',
#  'colombian pop',
#  'colombian rock',
#  'comedy rap',
#  'comic',
#  'comic metal',
#  'complextro',
#  'compositional ambient',
#  'conscious hip hop',
#  'contemporary country',
#  'contemporary vocal jazz',
#  'copla',
#  'corrido',
#  'country',
#  'country dawn',
#  'country rap',
#  'country rock',
#  'croatian pop',
#  'crossover thrash',
#  'crunk',
#  'cuarteto',
#  'cuatro venezolano',
#  'cubaton',
#  'cueca chilena',
#  'cumbia',
#  'cumbia chilena',
#  'cumbia ecuatoriana',
#  'cumbia paraguaya',
#  'cumbia peruana',
#  'cumbia pop',
#  'cumbia ranchera',
#  'cumbia sonidera',
#  'cumbia villera',
#  'cyber metal',
#  'cypriot pop',
#  'czech pop',
#  'dakke dak',
#  'dalarna indie',
#  'dance pop',
#  'dance rock',
#  'dancehall',
#  'dangdut',
#  'dangdut koplo',
#  'dangdut remix',
#  'danish alternative rock',
#  'danish electronic',
#  'danish electropop',
#  'danish hip hop',
#  'danish pop',
#  'danish pop rock',
#  'danish singer-songwriter',
#  'dansband',
#  'danseband',
#  'dansktop',
#  'danspunk',
#  'dark disco',
#  'dark trap',
#  'deconstructed club',
#  'deep big room',
#  'deep disco house',
#  'deep euro house',
#  'deep german hip hop',
#  'deep groove house',
#  'deep house',
#  'deep indian pop',
#  'deep italo disco',
#  'deep neofolk',
#  'deep pop edm',
#  'deep rai',
#  'deep soft rock',
#  'deep talent show',
#  'deep tech house',
#  'deep tropical house',
#  'deep turkish pop',
#  'deep underground hip hop',
#  'deep uplifting trance',
#  'dembow',
#  'desi hip hop',
#  'desi pop',
#  'destroy techno',
#  'detroit hip hop',
#  'detroit trap',
#  'detske pisnicky',
#  'devon indie',
#  'dfw rap',
#  'dirty south rap',
#  'disco',
#  'disco house',
#  'disco polo',
#  'discofox',
#  'disney',
#  'disney espanol',
#  'diva house',
#  'dmv rap',
#  'dominican indie',
#  'dominican pop',
#  'double drumming',
#  'downtempo',
#  'dream trance',
#  'drill espanol',
#  'drill francais',
#  'drill tuga',
#  'drum and bass',
#  'dubstep',
#  'dubsteppe',
#  'dutch americana',
#  'dutch cabaret',
#  'dutch drill',
#  'dutch edm',
#  'dutch hip hop',
#  'dutch house',
#  'dutch idol pop',
#  'dutch indie',
#  'dutch metal',
#  'dutch moombahton',
#  'dutch pop',
#  'dutch r&b',
#  'dutch rap pop',
#  'dutch singer-songwriter',
#  'dutch trance',
#  'dutch trap',
#  'early modern classical',
#  'early romantic era',
#  'east coast hip hop',
#  'easy listening',
#  'eau claire indie',
#  'ecuadorian alternative rock',
#  'ecuadorian pop',
#  'edm',
#  'edmonton indie',
#  'electra',
#  'electro',
#  'electro bailando',
#  'electro dub',
#  'electro house',
#  'electro latino',
#  'electro swing',
#  'electrofox',
#  'electronic trap',
#  'electronica',
#  'electronica argentina',
#  'electropop',
#  'electropowerpop',
#  'emo',
#  'emo mexicano',
#  'emo rap',
#  'emo rap italiano',
#  'english indie rock',
#  'epicore',
#  'escape room',
#  'estonian electronic',
#  'estonian hip hop',
#  'etherpop',
#  'eurodance',
#  'europop',
#  'eurovision',
#  'exotica',
#  'fado',
#  'filmi',
#  'filter house',
#  'finlandssvenska musik',
#  'finnish alternative rock',
#  'finnish blues',
#  'finnish choir',
#  'finnish dance pop',
#  'finnish death metal',
#  'finnish edm',
#  'finnish electro',
#  'finnish hard rock',
#  'finnish heavy metal',
#  'finnish hip hop',
#  'finnish idol pop',
#  'finnish indie',
#  'finnish jazz',
#  'finnish metal',
#  'finnish new wave',
#  'finnish pop',
#  'finnish punk',
#  'finnish reggae',
#  'finnish trap',
#  'firenze indie',
#  'flamenco',
#  'flamenco urbano',
#  'florida rap',
#  'folclore salteno',
#  'folk',
#  'folk black metal',
#  'folk brasileiro',
#  'folk rock',
#  'folk rock italiano',
#  'folk-pop',
#  'folklore chileno',
#  'folklore peruano',
#  'folklore veracruzano',
#  'football',
#  'forro',
#  'forro de favela',
#  'francoton',
#  'frauenrap',
#  'freak folk',
#  'french hip hop',
#  'french indie folk',
#  'french indie pop',
#  'french pop',
#  'french reggae',
#  'french shoegaze',
#  'french synthpop',
#  'funk',
#  'funk 150 bpm',
#  'funk bh',
#  'funk carioca',
#  'funk consciente',
#  'funk das antigas',
#  'funk metal',
#  'funk ostentacao',
#  'funk paulista',
#  'funk pop',
#  'future bass',
#  'futurepop',
#  'g funk',
#  'gabba',
#  'gaming dubstep',
#  'gaming edm',
#  'gangster rap',
#  'garage rock',
#  'gauze pop',
#  'german alternative rap',
#  'german alternative rock',
#  'german cloud rap',
#  'german dance',
#  'german drill',
#  'german hard rock',
#  'german hip hop',
#  'german house',
#  'german indie',
#  'german pop',
#  'german pop rock',
#  'german r&b',
#  'german rock',
#  'german show tunes',
#  'german soundtrack',
#  'german trap',
#  'german underground rap',
#  'girl group',
#  'glam metal',
#  'glam rock',
#  'glasgow indie',
#  'glee club',
#  'glitchcore',
#  'goralski',
#  'gospel',
#  'gospel italiano',
#  'gothenburg hip hop',
#  'gothenburg indie',
#  'gothic symphonic metal',
#  'gotlandsk musik',
#  'gqom',
#  'granada indie',
#  'graz indie',
#  'greek hip hop',
#  'greek house',
#  'greek indie',
#  'greenlandic pop',
#  'grime',
#  'groove room',
#  'grupera',
#  'gruperas inmortales',
#  'guadalajara indie',
#  'guaracha',
#  'guatemalan pop',
#  'hakkapop',
#  'halifax indie',
#  'halloween',
#  'hamburg electronic',
#  'hands up',
#  'hard bass',
#  'hard rock',
#  'hawaiian hip hop',
#  'heartland rock',
#  'hi-nrg',
#  'hip hop',
#  'hip hop quebecois',
#  'hip hop tuga',
#  'hip house',
#  'hip pop',
#  'hoerspiel',
#  'hokkien pop',
#  'hollywood',
#  'hong kong hip hop',
#  'hong kong indie',
#  'hopebeat',
#  'horror synth',
#  'house',
#  'houston rap',
#  'hungarian metal',
#  'hungarian pop',
#  'icelandic electronic',
#  'icelandic folk',
#  'icelandic indie',
#  'icelandic pop',
#  'idol',
#  'indie anthem-folk',
#  'indie cafe pop',
#  'indie deutschrap',
#  'indie electropop',
#  'indie extremena',
#  'indie folk',
#  'indie folk italiano',
#  'indie liguria',
#  'indie pop',
#  'indie pop rap',
#  'indie poptimism',
#  'indie rock',
#  'indie rock italiano',
#  'indie rock mexicano',
#  'indie rock peruano',
#  'indie rockism',
#  'indie singer-songwriter',
#  'indie soul',
#  'indie tico',
#  'indie triste',
#  'indiecoustica',
#  'indietronica',
#  'indonesian alternative rock',
#  'indonesian city pop',
#  'indonesian edm',
#  'indonesian emo',
#  'indonesian folk',
#  'indonesian hip hop',
#  'indonesian idol pop',
#  'indonesian indie',
#  'indonesian jazz',
#  'indonesian pop',
#  'indonesian pop punk',
#  'indonesian r&b',
#  'indonesian rock',
#  'indy indie',
#  'instrumental math rock',
#  'irish ballad',
#  'irish country',
#  'irish hip hop',
#  'irish indie',
#  'irish pop',
#  'irish rock',
#  'irish singer-songwriter',
#  'iskelma',
#  'isle of wight indie',
#  'israeli indie',
#  'israeli pop',
#  'italian adult pop',
#  'italian alternative',
#  'italian hip hop',
#  'italian indie pop',
#  'italian new wave',
#  'italian pop',
#  'italian progressive rock',
#  'italo dance',
#  'j-dance',
#  'j-division',
#  'j-idol',
#  'j-pop',
#  'j-rock',
#  'jam band',
#  'japanese alternative rock',
#  'japanese r&b',
#  'javanese dangdut',
#  'jawaiian',
#  'jazz blues',
#  'jazz funk',
#  'jazz pop',
#  'jersey club',
#  'jewish pop',
#  'jovem guarda',
#  'jump up',
#  'k-indie',
#  'k-pop',
#  'k-pop boy group',
#  'k-pop girl group',
#  'k-rap',
#  'kabyle',
#  'karadeniz halk muzigi',
#  'karneval',
#  'kawaii future bass',
#  'kazakh pop',
#  'kentucky hip hop',
#  'kentucky indie',
#  'kenyan pop',
#  'kindermusik',
#  'kiwi rock',
#  'kizomba',
#  'kleinkunst',
#  'kolsche karneval',
#  'korean ost',
#  'korean pop',
#  'korean r&b',
#  'kurdish pop',
#  'la indie',
#  'la pop',
#  'latin',
#  'latin alternative',
#  'latin arena pop',
#  'latin christian',
#  'latin hip hop',
#  'latin jazz',
#  'latin pop',
#  'latin rock',
#  'latin talent show',
#  'latin viral pop',
#  'latin worship',
#  'latintronica',
#  'lds youth',
#  'leeds indie',
#  'lilith',
#  'lithuanian electronic',
#  'lithuanian pop',
#  'lo-fi beats',
#  'lo-fi cover',
#  'london indie',
#  'london rap',
#  'lustrum',
#  'luxembourgian hip hop',
#  'macedonian pop',
#  'madchester',
#  'mainland chinese pop',
#  'malay rap',
#  'malaysian hip hop',
#  'malaysian indie',
#  'malaysian mandopop',
#  'malaysian pop',
#  'malaysian tamil pop',
#  'maltese pop',
#  'mambo chileno',
#  'manchester hip hop',
#  'mandopop',
#  'marching band',
#  'mariachi',
#  'melancholia',
#  'melbourne bounce',
#  'melbourne bounce international',
#  'mellow gold',
#  'melodic metalcore',
#  'melodic rap',
#  'melodipop',
#  'meme rap',
#  'memphis hip hop',
#  'merengue',
#  'metal',
#  'metropopolis',
#  'mexican edm',
#  'mexican hip hop',
#  'mexican indie',
#  'mexican pop',
#  'miami hip hop',
#  'midwest americana',
#  'military band',
#  'milwaukee indie',
#  'modern alternative pop',
#  'modern alternative rock',
#  'modern blues',
#  'modern blues rock',
#  'modern folk rock',
#  'modern indie pop',
#  'modern reggae',
#  'modern rock',
#  'modern salsa',
#  'moombahton',
#  'moroccan pop',
#  'motown',
#  'movie tunes',
#  'mpb',
#  'mundart',
#  'music hall',
#  'musica andina',
#  'musica andorra',
#  'musica catalana',
#  'musica costarricense',
#  'musica de intervencao',
#  'musica etnica',
#  'musica gaucha',
#  'musica para ninos',
#  'musica popular colombiana',
#  'musica portuguesa contemporanea',
#  'musical advocacy',
#  'musiikkia lapsille',
#  'musik anak-anak',
#  'musique guadeloupe',
#  'muziek voor kinderen',
#  'nasheed',
#  'nashville singer-songwriter',
#  'nashville sound',
#  'native american',
#  'nederlandse hardstyle',
#  'neo mellow',
#  'neo r&b',
#  'neo soul',
#  'neo-psychedelic',
#  'neo-singer-songwriter',
#  'neomelodici',
#  'neon pop punk',
#  'nerdcore brasileiro',
#  'new french touch',
#  'new jersey rap',
#  'new wave pop',
#  'new weird finland',
#  'nordic house',
#  'norges stemme',
#  'norteno',
#  'north carolina hip hop',
#  'norwegian choir',
#  'norwegian classical',
#  'norwegian contemporary jazz',
#  'norwegian country',
#  'norwegian hip hop',
#  'norwegian indie',
#  'norwegian pop',
#  'norwegian pop rap',
#  'nova mpb',
#  'novelty',
#  'nu-cumbia',
#  'nueva cancion',
#  'nuevo flamenco',
#  'nuevo regional mexicano',
#  'nyc pop',
#  'nyc rap',
#  'nz electronic',
#  'nz hip hop',
#  'nz pop',
#  'nz reggae',
#  'ohio hip hop',
#  'oktoberfest',
#  'operatic pop',
#  'operetta',
#  'opm',
#  'orebro indie',
#  'oriental metal',
#  'oslo indie',
#  'ottawa rap',
#  'oulu indie',
#  'oyun havasi',
#  'pagode',
#  'palm desert scene',
#  'panamanian pop',
#  'partyschlager',
#  'permanent wave',
#  'perreo',
#  'persian pop',
#  'peruvian rock',
#  'piano rock',
#  'pinoy alternative rap',
#  'pinoy hip hop',
#  'pinoy indie',
#  'pinoy r&b',
#  'pinoy singer-songwriter',
#  'pittsburgh indie',
#  'poezja spiewana',
#  'polish alternative',
#  'polish alternative rap',
#  'polish alternative rock',
#  'polish blues',
#  'polish electronica',
#  'polish hip hop',
#  'polish indie',
#  'polish metal',
#  'polish pop',
#  'polish punk',
#  'polish rock',
#  'polish trap',
#  'polynesian pop',
#  'pop',
#  'pop argentino',
#  'pop chileno',
#  'pop costarricense',
#  'pop dance',
#  'pop edm',
#  'pop flamenco',
#  'pop folk',
#  'pop house',
#  'pop nacional',
#  'pop peruano',
#  'pop punk',
#  'pop quebecois',
#  ...]

# %%
countries = list(df_feature_engineered.columns)[69:104]

# %%
len(countries)
# Out:
# 35

# %% [markdown]
# # Modeling

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import warnings
from sklearn.neighbors import KNeighborsRegressor
warnings.filterwarnings('ignore')

# %%
cols_with_na = [val for val in df_feature_engineered.columns if df_feature_engineered[val].isna().sum() > 0]

# %%
cols_with_na
# Out:
# ['Days_since_release',
#  'syuzhet_norm',
#  'bing_norm',
#  'afinn_norm',
#  'nrc_norm',
#  'syuzhet',
#  'bing',
#  'afinn',
#  'nrc',
#  'anger',
#  'anticipation',
#  'disgust',
#  'fear',
#  'joy',
#  'sadness',
#  'surprise',
#  'trust',
#  'negative',
#  'positive',
#  'n_words',
#  'anger_norm',
#  'anticipation_norm',
#  'disgust_norm',
#  'fear_norm',
#  'joy_norm',
#  'sadness_norm',
#  'surprise_norm',
#  'trust_norm',
#  'negative_norm',
#  'positive_norm',
#  'negative_bog_jr',
#  'positive_bog_jr',
#  'Bayes',
#  'Negative_Bayes',
#  'Neutral_Bayes',
#  'Positive_Bayes',
#  'Celebrate',
#  'Desire',
#  'Explore',
#  'Fun',
#  'Hope',
#  'Love',
#  'Nostalgia',
#  'Thug']

# %%
num_transformer_w_standardizer = Pipeline([('imputer',SimpleImputer(missing_values=np.nan,strategy='mean')),
('scaler', StandardScaler())])

num_transformer_no_scaling = Pipeline([('imputer',SimpleImputer(missing_values=np.nan,strategy='mean'))])

num_transformer_w_minmaxscaler = Pipeline([('imputer',SimpleImputer(missing_values=np.nan,strategy='mean')),
                                           ('scaler', MinMaxScaler())])

cat_transformer = Pipeline([
('imputer', SimpleImputer(missing_values=np.nan,strategy='most_frequent')),('onehot',OneHotEncoder(handle_unknown='ignore'))])

# %%
preprocessor_standardscaler = ColumnTransformer([
        ('num', num_transformer_w_standardizer, cols_with_na)])

# preprocessor_noscaler = ColumnTransformer([
#         ('num', num_transformer_no_scaling, quantitave_attr),
#         ('cat', cat_transformer, cateorical_attributes)])


# preprocessor_minmaxscaler = ColumnTransformer([
#         ('num', num_transformer_w_minmaxscaler, quantitave_attr),
#         ('cat', cat_transformer, cateorical_attributes)])

# %%
def print_scores(data,label,data_type,features,country):
    best_model = None
    best_r2_score = float('-inf')
    best_mae_score = float('-inf')
    best_rmse_score = float('-inf')
    data = data[data[country]==1]
    country_df = pd.DataFrame(columns = ['Model','R2','MAE','RMSE'])
    model_param_pairs = [(linear_model.Lasso(),
                          [{'reg__alpha':[0,0.5,1],'reg__fit_intercept':[True,False]}]),
                          (linear_model.Ridge(),
                           [{'reg__alpha':[0,0.5,1],'reg__fit_intercept':[True,False]}]),
                          (DecisionTreeRegressor(),
                           [{'reg__criterion':["squared_error", "friedman_mse", "absolute_error", "poisson"],'reg__splitter':["random","best"]}]),
                          (RandomForestRegressor(),
                           [{'reg__criterion':["squared_error", "friedman_mse", "absolute_error", "poisson"],'reg__max_features':["sqrt","log2"]}]),
                          (SVR(),
                           [{'reg__kernel':["linear", "poly", "rbf", "sigmoid", "precomputed"],'reg__gamma':["scale","auto"]}]),
                          (KNeighborsRegressor(),
                           [{'reg__n_neighbors':[3, 5, 9, 14],'reg__weights':["uniform","distance"]}])]
    
    for model_param_pair in tqdm(model_param_pairs):
        model = model_param_pair[0]
        print(model)
        model_no_params = model
        
        param_grid = model_param_pair[1]
        
        pipe_reg = Pipeline([('preprocess',preprocessor_standardscaler),
                            ('reg', model)])


        kf = KFold(n_splits=5,random_state=42,shuffle=True)      
        grid_search = GridSearchCV(pipe_reg,param_grid,cv=kf,scoring = ['r2'],refit='r2')


        grid_search.fit(data[features], data[label])
        r2 = grid_search.best_score_
            

        #create pipeline with best params identified
        pipe_reg_best = Pipeline([('preprocess',preprocessor_standardscaler),
                            ('reg', model)])

        pipe_reg_best.set_params(**grid_search.best_params_)
    #     print(pipe_reg_best)


    #     return grid_search


    #     print(data[features])
    #     print(data[label])
        
        #r2 score
#         r2 = cross_val_score(pipe_reg_best, data[features], data[label],cv=kf,scoring='r2')

#         print(r2)

#         print("data type: {}\nlabel: {}\nmodel : {}\n country: {}".format(data_type,label,model_name,country))
#         print("r2 score: {}".format(np.mean(r2)))
#         print()

    #     variance = cross_val_score(pipe_cls, data[features], data[label],cv=kf,scoring='explained_variance')

    #     print("data type: {}\nlabel: {}\nmodel : {}\n country: {}".format(data_type,label,model,country))
    #     print("variance score: {}".format(np.mean(variance)))
    #     print()


        rmse_scores = cross_val_score(pipe_reg_best, data[features], data[label],cv=kf,scoring='neg_root_mean_squared_error')
            
#         print("data type: {}\nlabel: {}\nmodel : {}\n country: {}".format(data_type,label,model,country))
#         print("rmse score: {}".format(-1*np.mean(rmse)))
#         print()
        rmse = -1*np.mean(rmse_scores)
        mae_scores = cross_val_score(pipe_reg_best, data[features], data[label],cv=kf,scoring='neg_mean_absolute_error')
        mae = -1*np.mean(mae_scores)
        
        country_df = country_df
        
        
        country_df.loc[len(country_df.index)] = [str(model_no_params), r2, mae, rmse]
        
        if(grid_search.best_score_ > best_r2_score):
            best_r2_score = grid_search.best_score_
            best_model = str(model)
            #save model
            with open(MODELS_PATH + country + '_best_model.pkl','wb') as f:
                pickle.dump(grid_search,f)
                
            best_mae_score = mae
            best_rmse_score = rmse
            
            
    print()

    return country_df,best_model,best_r2_score,best_rmse_score,best_mae_score

# %%
features_columns = [column for column in df_feature_engineered.columns if column!='Popularity']

# %%
len(features_columns)
# Out:
# 1228

# %%
countries
# Out:
# ['Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Denmark',
#  'Ecuador',
#  'Finland',
#  'France',
#  'Germany',
#  'Global',
#  'Indonesia',
#  'Ireland',
#  'Italy',
#  'Malaysia',
#  'Mexico',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Singapore',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Turkey',
#  'UK',
#  'USA']

# %%
country_wise_results = dict()
overall_results_df = pd.DataFrame(columns = ['Country','Best model','Best r2','Best RMSE','Best MAE'])

for country in countries[:16]:
    print(country)
    country_df,best_model,best_r2,best_rmse,best_mae = print_scores(df_feature_engineered,'Popularity','imputed_df',features_columns,country)
    country_wise_results[country] = country_df
    overall_results_df.loc[len(overall_results_df)] = [country,best_model,best_r2,best_rmse,best_mae]
# Out:
# Argentina
#   0%|          | 0/6 [00:00<?, ?it/s]
# Lasso()
# Ridge()
# DecisionTreeRegressor()
# RandomForestRegressor()
# SVR()
# KNeighborsRegressor()
#
# Australia
#   0%|          | 0/6 [00:00<?, ?it/s]
# Lasso()
# Ridge()
# DecisionTreeRegressor()
# RandomForestRegressor()
# SVR()
# KNeighborsRegressor()
#
# Austria
#   0%|          | 0/6 [00:00<?, ?it/s]
# Lasso()
# Ridge()
# DecisionTreeRegressor()
# RandomForestRegressor()
# SVR()
# KNeighborsRegressor()
#
# Belgium
#   0%|          | 0/6 [00:00<?, ?it/s]
# Lasso()
# Ridge()
# DecisionTreeRegressor()
# RandomForestRegressor()

# %%
country_wise_results['Argentina']
# Out:
#                                                Model        R2           MAE  \
# 0                                     Lasso(alpha=1) -0.011117  10815.150837
# 1                                     Ridge(alpha=1) -0.011197  10815.940604
# 2  DecisionTreeRegressor(criterion='poisson', spl... -0.513048  12233.543863
# 3  RandomForestRegressor(criterion='friedman_mse'... -0.211668  11321.773527
# 4                               SVR(kernel='linear') -0.213614   8517.610958
# 5                KNeighborsRegressor(n_neighbors=14) -0.027660  10582.346388
#
#            RMSE
# 0  16316.535696
# 1  16317.162875
# 2  19408.983964
# 3  17834.389890
# 4  17870.572222
# 5  16436.383578

# %%
overall_results_df
# Out:
#      Country      Best model   Best r2     Best RMSE      Best MAE
# 0  Argentina  Lasso(alpha=1) -0.011117  16316.535696  10815.150837

# %% [markdown]
# ### Predictions -

# %%
# load
country_model = None
with open(MODELS_PATH + 'Argentina_best_model.pkl', 'rb') as f:
    country_model = pickle.load(f)

# %%
sample_data = df_feature_engineered[df_feature_engineered['USA']==1]

# %%
sample_data
# Out:
#        Popularity  Artist_followers  Track_number  Tracks_in_album  \
# 1            8.00        11427104.0             1                1
# 17         581.20        16931568.0             7               12
# 40         100.25         5910376.0             1                1
# 59          56.00         8092392.0             7               11
# 81          62.40        17132813.0             3               10
# ...           ...               ...           ...              ...
# 89414      247.20         1262102.0            14               15
# 89420       28.00          711265.0             5                7
# 89421      364.65         5004777.0             1                1
# 89422     4919.35         5647016.0             1               10
# 89424     1361.00         4184476.0             5               16
#
#        danceability  energy   key  loudness  mode  speechiness  ...  \
# 1             0.767   0.709   1.0    -4.470   1.0       0.3360  ...
# 17            0.572   0.530   6.0    -8.521   0.0       0.0654  ...
# 40            0.488   0.538   6.0    -4.974   1.0       0.0760  ...
# 59            0.515   0.917   1.0    -7.312   1.0       0.0417  ...
# 81            0.593   0.712   2.0    -6.325   0.0       0.0286  ...
# ...             ...     ...   ...       ...   ...          ...  ...
# 89414         0.469   0.080   2.0   -15.489   1.0       0.0425  ...
# 89420         0.711   0.462  10.0    -7.132   0.0       0.0550  ...
# 89421         0.615   0.871   1.0    -5.308   1.0       0.0894  ...
# 89422         0.863   0.576   5.0    -5.687   0.0       0.2390  ...
# 89424         0.512   0.580   3.0    -6.658   0.0       0.0290  ...
#
#        viral rap  vlaamse kinderliedje  vocal harmony group  volkspop  \
# 1            0.0                   0.0                  0.0       0.0
# 17           0.0                   0.0                  0.0       0.0
# 40           0.0                   0.0                  0.0       0.0
# 59           0.0                   0.0                  0.0       0.0
# 81           0.0                   0.0                  0.0       0.0
# ...          ...                   ...                  ...       ...
# 89414        0.0                   0.0                  0.0       0.0
# 89420        0.0                   0.0                  0.0       0.0
# 89421        0.0                   0.0                  0.0       0.0
# 89422        0.0                   0.0                  0.0       0.0
# 89424        0.0                   0.0                  0.0       0.0
#
#        world chill  zimdancehall  zouk riddim    year  month   day
# 1              0.0           0.0          0.0  2018.0   11.0   5.0
# 17             0.0           0.0          0.0  2017.0    4.0   7.0
# 40             0.0           0.0          0.0  2017.0    8.0   3.0
# 59             0.0           0.0          0.0  2017.0    9.0  15.0
# 81             0.0           0.0          0.0  2017.0    5.0  19.0
# ...            ...           ...          ...     ...    ...   ...
# 89414          0.0           0.0          0.0  2020.0    4.0  17.0
# 89420          0.0           0.0          0.0  2016.0   12.0  23.0
# 89421          0.0           0.0          0.0  2017.0    4.0  14.0
# 89422          0.0           0.0          0.0  2016.0    8.0  26.0
# 89424          0.0           0.0          0.0  2019.0   11.0  22.0
#
# [6645 rows x 1229 columns]

# %%
predictions = country_model.predict(sample_data[features_columns])
sample_data['Predicted Popularity in '+ 'Argentina'] = predictions

# %%
sample_data.sort_values('Predicted Popularity in Argentina',ascending=False)
# Out:
#        Popularity  Artist_followers  Track_number  Tracks_in_album  \
# 86362       31.20         4222467.0             1                1
# 87078       31.20         4222467.0             1                1
# 86870      409.60          385840.0             3               46
# 49024    38761.20        10919803.0             6               24
# 81553      353.35         5004777.0            13               13
# ...           ...               ...           ...              ...
# 87018       43.20         3724826.0             2               14
# 28788      164.80         6028580.0             3               10
# 84908      395.20        11968318.0            10               10
# 50869      791.75           61128.0            10               14
# 40709     2089.65        16280782.0             4               30
#
#        danceability  energy   key  loudness  mode  speechiness  ...  \
# 86362         0.662   0.866   6.0    -3.328   1.0       0.1590  ...
# 87078         0.663   0.875   6.0    -3.301   1.0       0.1830  ...
# 86870         0.698   0.649   8.0    -6.764   1.0       0.4150  ...
# 49024         0.907   0.633   2.0    -5.145   1.0       0.1840  ...
# 81553         0.531   0.797  10.0    -7.018   1.0       0.1540  ...
# ...             ...     ...   ...       ...   ...          ...  ...
# 87018         0.621   0.854   1.0    -3.697   1.0       0.3200  ...
# 28788         0.368   0.505   4.0    -7.208   1.0       0.0285  ...
# 84908         0.701   0.485  11.0   -10.305   0.0       0.3640  ...
# 50869         0.549   0.449   9.0   -13.645   0.0       0.1040  ...
# 40709         0.773   0.859  11.0    -4.913   1.0       0.0747  ...
#
#        vlaamse kinderliedje  vocal harmony group  volkspop  world chill  \
# 86362                   0.0                  0.0       0.0          0.0
# 87078                   0.0                  0.0       0.0          0.0
# 86870                   0.0                  0.0       0.0          0.0
# 49024                   0.0                  0.0       0.0          0.0
# 81553                   0.0                  0.0       0.0          0.0
# ...                     ...                  ...       ...          ...
# 87018                   0.0                  0.0       0.0          0.0
# 28788                   0.0                  0.0       0.0          0.0
# 84908                   0.0                  0.0       0.0          0.0
# 50869                   0.0                  0.0       0.0          0.0
# 40709                   0.0                  0.0       0.0          0.0
#
#        zimdancehall  zouk riddim    year  month   day  \
# 86362           0.0          0.0  2018.0    1.0  12.0
# 87078           0.0          0.0  2018.0    1.0  12.0
# 86870           0.0          0.0  2015.0    9.0  25.0
# 49024           0.0          0.0  2018.0    1.0  26.0
# 81553           0.0          0.0  2017.0    5.0   5.0
# ...             ...          ...     ...    ...   ...
# 87018           0.0          0.0  2018.0    9.0   7.0
# 28788           0.0          0.0  1994.0   11.0   1.0
# 84908           0.0          0.0  2016.0   12.0   9.0
# 50869           0.0          0.0  2018.0    2.0   9.0
# 40709           0.0          0.0  1982.0   11.0  30.0
#
#        Predicted Popularity in Argentina
# 86362                       33133.851999
# 87078                       33133.851999
# 86870                       28793.187881
# 49024                       28552.997011
# 81553                       25929.981109
# ...                                  ...
# 87018                       -8177.984660
# 28788                       -9022.789850
# 84908                      -10898.057601
# 50869                      -11478.964275
# 40709                      -13897.539470
#
# [6645 rows x 1230 columns]
